# %% [markdown]
# ### In this module we will run YOLO on our test set and analyze its outputs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
from ultralytics import YOLO
import torch
os.sys.path.append('../utils') #To load master_configuration.yaml
from readYAML import read_config_file #To load in master configuration

# %% [markdown]
# ### Once again let

# %% [markdown]
# ### Load test set

# %%
'''No noise'''
#df = pd.read_feather("data/test.feather")

'''Noise'''
df = pd.read_feather("data/test_noise.feather")

# %% [markdown]
# # Now let's evaluate YOLO on the test images
#
# After training yolo it will create a directory called *runs/*. You'll need to navigate through runs and find the
# desired model you trained. In the example below *train13/* is the directory that we're using. The *weights/* subdirectory contains two files, one called 'best' and the other called 'last'. 'best' is the saved weights file during the best performing epoch of training. It's typically best to use this file.

# %%
log = False
noise = True

from PIL import Image

#Directory of the test PNG images we created
if log:
    if not noise:
        testpath = 'datasets/test_log/images/'
    else:
        testpath = 'datasets/test_log_noise/images/'
else:
    if not noise:
        testpath = 'datasets/test/images/'
    else:
        testpath = 'datasets/test_noise/images/'

#Create a sorted list of PIL images to pass into YOLO
images = [Image.open(testpath+val) for val in sorted(os.listdir(testpath))]
print('Performing YOLO inference\n')

#Load trained YOLO model weights (you'll need to find this file)
if not log:
    if not noise:
        model = YOLO('models/raw_linear/train/weights/best.pt') #trained model
    else:
        model = YOLO('models/noise_linear/train/weights/best.pt') #trained model
else:
    if not noise:
        model = YOLO('models/raw_log/train/weights/best.pt') #trained model
    else:
        model = YOLO('models/noise_log/train/weights/best.pt') #trained model
#Perform YOLO inference on all images
results = model.predict(images,batch = len(images),verbose = False, workers = 1,imgsz=512,rect=True)
# Out:
# Performing YOLO inference

# %% [markdown]
# ### Let's take a closer look at the results file before analyzing

# %%
#The length of the results list should always be the same as the test dataframe
print(len(results),len(df))

#Looking through the results list, each entry has a boxes and keypoints object
results
# Out:
# 112 112
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   4,   0],
#          [255,   0,   0],
#          [255,  32,   0],
#          ...,
#          [255,  56,   0],
#          [255,  84,   0],
#          [255,  64,   0]],
#
#         [[236,   0,   0],
#          [255,  16,   0],
#          [255,  20,   0],
#          ...,
#          [255,  40,   0],
#          [255,   8,   0],
#          [254,   0,   0]],
#
#         [[255,  48,   0],
#          [255,  24,   0],
#          [255,  60,   0],
#          ...,
#          [250,   0,   0],
#          [255,  32,   0],
#          [255,  12,   0]],
#
#         ...,
#
#         [[255,  12,   0],
#          [255,  20,   0],
#          [204,   0,   0],
#          ...,
#          [255,  40,   0],
#          [204,   0,   0],
#          [209,   0,   0]],
#
#         [[255,  44,   0],
#          [172,   0,   0],
#          [255,  12,   0],
#          ...,
#          [255,  28,   0],
#          [255,  44,   0],
#          [250,   0,   0]],
#
#         [[255,   0,   0],
#          [241,   0,   0],
#          [255,  36,   0],
#          ...,
#          [255,  52,   0],
#          [255,   8,   0],
#          [213,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1006.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[254,   0,   0],
#          [255,  32,   0],
#          [255,   0,   0],
#          ...,
#          [255,  80,   0],
#          [232,   0,   0],
#          [255,   8,   0]],
#
#         [[255,  36,   0],
#          [255,   4,   0],
#          [245,   0,   0],
#          ...,
#          [255,  64,   0],
#          [255,  52,   0],
#          [255,   4,   0]],
#
#         [[255,   0,   0],
#          [232,   0,   0],
#          [245,   0,   0],
#          ...,
#          [250,   0,   0],
#          [255,  48,   0],
#          [236,   0,   0]],
#
#         ...,
#
#         [[255,   8,   0],
#          [222,   0,   0],
#          [200,   0,   0],
#          ...,
#          [241,   0,   0],
#          [255,   0,   0],
#          [255,  28,   0]],
#
#         [[255,  48,   0],
#          [255,  56,   0],
#          [245,   0,   0],
#          ...,
#          [218,   0,   0],
#          [255,   0,   0],
#          [255,  32,   0]],
#
#         [[255,  60,   0],
#          [250,   0,   0],
#          [255,  72,   0],
#          ...,
#          [255,  56,   0],
#          [255,  96,   0],
#          [255,  80,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1007.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[145,   0,   0],
#          [255,   0,   0],
#          [227,   0,   0],
#          ...,
#          [232,   0,   0],
#          [232,   0,   0],
#          [255,  44,   0]],
#
#         [[255,  32,   0],
#          [159,   0,   0],
#          [255,  64,   0],
#          ...,
#          [227,   0,   0],
#          [255,  44,   0],
#          [255, 100,   0]],
#
#         [[255,   0,   0],
#          [232,   0,   0],
#          [232,   0,   0],
#          ...,
#          [250,   0,   0],
#          [255,  60,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[255,  96,   0],
#          [209,   0,   0],
#          [222,   0,   0],
#          ...,
#          [255,   0,   0],
#          [177,   0,   0],
#          [255,  28,   0]],
#
#         [[255,  44,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [245,   0,   0],
#          [254,   0,   0],
#          [232,   0,   0]],
#
#         [[255,  48,   0],
#          [255,   8,   0],
#          [254,   0,   0],
#          ...,
#          [232,   0,   0],
#          [195,   0,   0],
#          [222,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1008.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[250,   0,   0],
#          [255,  32,   0],
#          [254,   0,   0],
#          ...,
#          [255, 144,   0],
#          [232,   0,   0],
#          [255,   0,   0]],
#
#         [[255, 116,   0],
#          [255,  40,   0],
#          [255,  24,   0],
#          ...,
#          [222,   0,   0],
#          [255,  44,   0],
#          [255,  64,   0]],
#
#         [[255,   4,   0],
#          [200,   0,   0],
#          [255,   8,   0],
#          ...,
#          [255,   0,   0],
#          [255,  80,   0],
#          [186,   0,   0]],
#
#         ...,
#
#         [[255,  12,   0],
#          [255,   0,   0],
#          [163,   0,   0],
#          ...,
#          [255,  52,   0],
#          [255,  28,   0],
#          [227,   0,   0]],
#
#         [[255,   0,   0],
#          [255,   0,   0],
#          [236,   0,   0],
#          ...,
#          [255,  44,   0],
#          [255,   4,   0],
#          [255,  28,   0]],
#
#         [[255, 100,   0],
#          [245,   0,   0],
#          [255, 104,   0],
#          ...,
#          [255,  12,   0],
#          [255,  48,   0],
#          [241,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1009.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  20,   0],
#          [232,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,   8,   0],
#          [255,  68,   0],
#          [255,   0,   0]],
#
#         [[255,   0,   0],
#          [255,   4,   0],
#          [255,   8,   0],
#          ...,
#          [218,   0,   0],
#          [255,  24,   0],
#          [255,  12,   0]],
#
#         [[255,  68,   0],
#          [255,  12,   0],
#          [255,   0,   0],
#          ...,
#          [255, 116,   0],
#          [255,  36,   0],
#          [255, 112,   0]],
#
#         ...,
#
#         [[255,   4,   0],
#          [255,  24,   0],
#          [254,   0,   0],
#          ...,
#          [255,   0,   0],
#          [255,  52,   0],
#          [241,   0,   0]],
#
#         [[255,  60,   0],
#          [250,   0,   0],
#          [254,   0,   0],
#          ...,
#          [255,  52,   0],
#          [245,   0,   0],
#          [255,   0,   0]],
#
#         [[250,   0,   0],
#          [241,   0,   0],
#          [255,  72,   0],
#          ...,
#          [245,   0,   0],
#          [255,   0,   0],
#          [232,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1010.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  24,   0],
#          [222,   0,   0],
#          [255,  64,   0],
#          ...,
#          [255,   0,   0],
#          [255,  48,   0],
#          [209,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  56,   0],
#          [255,  48,   0],
#          ...,
#          [236,   0,   0],
#          [255,  64,   0],
#          [245,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  32,   0],
#          [227,   0,   0],
#          ...,
#          [241,   0,   0],
#          [255,  20,   0],
#          [255,  12,   0]],
#
#         ...,
#
#         [[255,   0,   0],
#          [255,  48,   0],
#          [195,   0,   0],
#          ...,
#          [255,  36,   0],
#          [255,   0,   0],
#          [255,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  36,   0],
#          [222,   0,   0],
#          ...,
#          [255,  76,   0],
#          [255,  72,   0],
#          [255,  36,   0]],
#
#         [[255,  24,   0],
#          [255,  20,   0],
#          [255,  40,   0],
#          ...,
#          [255,  80,   0],
#          [255,  40,   0],
#          [255,   8,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1011.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[222,   0,   0],
#          [254,   0,   0],
#          [204,   0,   0],
#          ...,
#          [245,   0,   0],
#          [172,   0,   0],
#          [254,   0,   0]],
#
#         [[145,   0,   0],
#          [255,   0,   0],
#          [255,  52,   0],
#          ...,
#          [241,   0,   0],
#          [255,  56,   0],
#          [250,   0,   0]],
#
#         [[227,   0,   0],
#          [250,   0,   0],
#          [255, 140,   0],
#          ...,
#          [255,   8,   0],
#          [255, 124,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[163,   0,   0],
#          [227,   0,   0],
#          [255,  28,   0],
#          ...,
#          [255,  64,   0],
#          [213,   0,   0],
#          [227,   0,   0]],
#
#         [[255,  48,   0],
#          [255,   0,   0],
#          [255,  24,   0],
#          ...,
#          [255,   4,   0],
#          [255,  28,   0],
#          [255,  32,   0]],
#
#         [[241,   0,   0],
#          [250,   0,   0],
#          [255,   8,   0],
#          ...,
#          [255,  20,   0],
#          [255,   4,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1012.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  92,   0],
#          [255,  28,   0],
#          [255,  88,   0],
#          ...,
#          [255,   4,   0],
#          [255,   0,   0],
#          [250,   0,   0]],
#
#         [[255,  44,   0],
#          [255,  36,   0],
#          [255,  88,   0],
#          ...,
#          [255,  16,   0],
#          [255,   0,   0],
#          [255,  16,   0]],
#
#         [[236,   0,   0],
#          [255,  32,   0],
#          [255, 100,   0],
#          ...,
#          [241,   0,   0],
#          [204,   0,   0],
#          [241,   0,   0]],
#
#         ...,
#
#         [[255,  24,   0],
#          [227,   0,   0],
#          [255,  32,   0],
#          ...,
#          [255,  12,   0],
#          [255,  12,   0],
#          [241,   0,   0]],
#
#         [[255,  52,   0],
#          [255,   4,   0],
#          [254,   0,   0],
#          ...,
#          [241,   0,   0],
#          [255,  24,   0],
#          [255,   8,   0]],
#
#         [[255,  24,   0],
#          [255,   8,   0],
#          [255,  32,   0],
#          ...,
#          [255,  60,   0],
#          [255,  44,   0],
#          [255,  48,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1013.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  60,   0],
#          [255,  72,   0],
#          [255,  20,   0],
#          ...,
#          [191,   0,   0],
#          [255,  32,   0],
#          [255,  40,   0]],
#
#         [[255,   0,   0],
#          [222,   0,   0],
#          [255,  68,   0],
#          ...,
#          [255,  52,   0],
#          [191,   0,   0],
#          [218,   0,   0]],
#
#         [[255,  40,   0],
#          [255,   8,   0],
#          [191,   0,   0],
#          ...,
#          [255,  24,   0],
#          [186,   0,   0],
#          [255,  68,   0]],
#
#         ...,
#
#         [[255,  32,   0],
#          [255,   0,   0],
#          [236,   0,   0],
#          ...,
#          [255,  28,   0],
#          [254,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  44,   0],
#          [255,   0,   0],
#          [195,   0,   0],
#          ...,
#          [255,  20,   0],
#          [255,  16,   0],
#          [255,  16,   0]],
#
#         [[255,  40,   0],
#          [236,   0,   0],
#          [213,   0,   0],
#          ...,
#          [255,  68,   0],
#          [255,  12,   0],
#          [255,  28,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1014.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[213,   0,   0],
#          [255,  84,   0],
#          [255,  60,   0],
#          ...,
#          [255,   0,   0],
#          [236,   0,   0],
#          [241,   0,   0]],
#
#         [[255,  32,   0],
#          [255,  56,   0],
#          [255,   8,   0],
#          ...,
#          [255,   4,   0],
#          [255, 108,   0],
#          [236,   0,   0]],
#
#         [[255,  36,   0],
#          [177,   0,   0],
#          [254,   0,   0],
#          ...,
#          [255,  44,   0],
#          [255,   0,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[255,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  40,   0],
#          [250,   0,   0],
#          [255,  32,   0]],
#
#         [[255,   4,   0],
#          [255,   8,   0],
#          [255,  32,   0],
#          ...,
#          [255, 100,   0],
#          [255,  44,   0],
#          [255,   8,   0]],
#
#         [[255,  36,   0],
#          [255,  52,   0],
#          [255,  48,   0],
#          ...,
#          [255,  36,   0],
#          [245,   0,   0],
#          [255,  36,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1015.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   0,   0],
#          [255,  56,   0],
#          [255, 120,   0],
#          ...,
#          [255,  52,   0],
#          [255,  96,   0],
#          [255,  28,   0]],
#
#         [[255,  88,   0],
#          [255,   0,   0],
#          [255,  92,   0],
#          ...,
#          [255,  40,   0],
#          [255,  96,   0],
#          [255,   4,   0]],
#
#         [[255,  64,   0],
#          [168,   0,   0],
#          [255,  28,   0],
#          ...,
#          [255,  32,   0],
#          [209,   0,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[255,  80,   0],
#          [255,   4,   0],
#          [255,  84,   0],
#          ...,
#          [255,  36,   0],
#          [255,  36,   0],
#          [255,   4,   0]],
#
#         [[255,  72,   0],
#          [255,   4,   0],
#          [255,  36,   0],
#          ...,
#          [255,  60,   0],
#          [255,  48,   0],
#          [255,  12,   0]],
#
#         [[255,  64,   0],
#          [255,  36,   0],
#          [255,  24,   0],
#          ...,
#          [255,  64,   0],
#          [255,  72,   0],
#          [255,  28,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1016.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[204,   0,   0],
#          [255,  72,   0],
#          [163,   0,   0],
#          ...,
#          [255,   0,   0],
#          [241,   0,   0],
#          [255,  40,   0]],
#
#         [[232,   0,   0],
#          [254,   0,   0],
#          [255, 116,   0],
#          ...,
#          [255,  16,   0],
#          [255,  40,   0],
#          [255,  52,   0]],
#
#         [[255,   0,   0],
#          [255,  60,   0],
#          [255,  20,   0],
#          ...,
#          [255,   8,   0],
#          [255,  48,   0],
#          [255,  36,   0]],
#
#         ...,
#
#         [[255,  60,   0],
#          [255,   4,   0],
#          [255, 120,   0],
#          ...,
#          [255,   0,   0],
#          [254,   0,   0],
#          [213,   0,   0]],
#
#         [[255,  32,   0],
#          [255,  92,   0],
#          [255,  52,   0],
#          ...,
#          [255,  52,   0],
#          [255,  36,   0],
#          [255,   4,   0]],
#
#         [[177,   0,   0],
#          [163,   0,   0],
#          [254,   0,   0],
#          ...,
#          [255,  52,   0],
#          [236,   0,   0],
#          [186,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1017.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  80,   0],
#          [255, 128,   0],
#          [255,   0,   0],
#          ...,
#          [255,  16,   0],
#          [255,  20,   0],
#          [255,  44,   0]],
#
#         [[255,  44,   0],
#          [232,   0,   0],
#          [255,  32,   0],
#          ...,
#          [255,  32,   0],
#          [227,   0,   0],
#          [255,  56,   0]],
#
#         [[255,  64,   0],
#          [255,  64,   0],
#          [255,   0,   0],
#          ...,
#          [255,  12,   0],
#          [195,   0,   0],
#          [255,  44,   0]],
#
#         ...,
#
#         [[255,  16,   0],
#          [255,   0,   0],
#          [255,   4,   0],
#          ...,
#          [255,   0,   0],
#          [255,   0,   0],
#          [236,   0,   0]],
#
#         [[255,   0,   0],
#          [255,   8,   0],
#          [236,   0,   0],
#          ...,
#          [255,  20,   0],
#          [255,   8,   0],
#          [255,   0,   0]],
#
#         [[255,  32,   0],
#          [255,   8,   0],
#          [255,  80,   0],
#          ...,
#          [254,   0,   0],
#          [255,  68,   0],
#          [255,  72,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1018.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255, 108,   0],
#          [218,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,   0,   0],
#          [255,   4,   0],
#          [227,   0,   0]],
#
#         [[255,  68,   0],
#          [191,   0,   0],
#          [255,  84,   0],
#          ...,
#          [236,   0,   0],
#          [255,  28,   0],
#          [254,   0,   0]],
#
#         [[255,   8,   0],
#          [255,  12,   0],
#          [255,  24,   0],
#          ...,
#          [250,   0,   0],
#          [255,  44,   0],
#          [255, 108,   0]],
#
#         ...,
#
#         [[254,   0,   0],
#          [255,  32,   0],
#          [213,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,  52,   0],
#          [255,  48,   0]],
#
#         [[254,   0,   0],
#          [255,  28,   0],
#          [255,  84,   0],
#          ...,
#          [255,  20,   0],
#          [255,  16,   0],
#          [218,   0,   0]],
#
#         [[254,   0,   0],
#          [255,  44,   0],
#          [255,   0,   0],
#          ...,
#          [209,   0,   0],
#          [255,   0,   0],
#          [255,  12,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1019.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  68,   0],
#          [255,   0,   0],
#          [255,  80,   0],
#          ...,
#          [255,  32,   0],
#          [255,  32,   0],
#          [255,  12,   0]],
#
#         [[255,  48,   0],
#          [255,   0,   0],
#          [255,  56,   0],
#          ...,
#          [255,   0,   0],
#          [245,   0,   0],
#          [222,   0,   0]],
#
#         [[191,   0,   0],
#          [255,   0,   0],
#          [255,   4,   0],
#          ...,
#          [255,  24,   0],
#          [255,   0,   0],
#          [245,   0,   0]],
#
#         ...,
#
#         [[255,  64,   0],
#          [255,  72,   0],
#          [245,   0,   0],
#          ...,
#          [255,   0,   0],
#          [255,  40,   0],
#          [255,   0,   0]],
#
#         [[255,  28,   0],
#          [255,  16,   0],
#          [255,   8,   0],
#          ...,
#          [255,  36,   0],
#          [255,   4,   0],
#          [255,  56,   0]],
#
#         [[255,  28,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  40,   0],
#          [255,   0,   0],
#          [236,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1020.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  84,   0],
#          [150,   0,   0],
#          [255,  16,   0],
#          ...,
#          [255,   0,   0],
#          [255,   0,   0],
#          [255,  60,   0]],
#
#         [[255,  64,   0],
#          [218,   0,   0],
#          [168,   0,   0],
#          ...,
#          [255,   4,   0],
#          [241,   0,   0],
#          [255,   0,   0]],
#
#         [[255, 100,   0],
#          [255,  60,   0],
#          [245,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,   0,   0],
#          [255,  84,   0]],
#
#         ...,
#
#         [[255,   0,   0],
#          [255,  96,   0],
#          [255,   0,   0],
#          ...,
#          [195,   0,   0],
#          [255,  24,   0],
#          [213,   0,   0]],
#
#         [[255,  16,   0],
#          [255,  36,   0],
#          [255,  64,   0],
#          ...,
#          [172,   0,   0],
#          [232,   0,   0],
#          [255,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  60,   0],
#          [255,  44,   0],
#          ...,
#          [241,   0,   0],
#          [255,   4,   0],
#          [255,  48,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1021.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  44,   0],
#          [255,  48,   0],
#          [255,   0,   0],
#          ...,
#          [255,  12,   0],
#          [255,  48,   0],
#          [255,  40,   0]],
#
#         [[218,   0,   0],
#          [255,   0,   0],
#          [255,  44,   0],
#          ...,
#          [255,  68,   0],
#          [255,  44,   0],
#          [209,   0,   0]],
#
#         [[255,  80,   0],
#          [222,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  16,   0],
#          [255,  64,   0],
#          [222,   0,   0]],
#
#         ...,
#
#         [[250,   0,   0],
#          [232,   0,   0],
#          [255,  40,   0],
#          ...,
#          [255,  32,   0],
#          [255,   0,   0],
#          [255, 116,   0]],
#
#         [[255,   4,   0],
#          [255, 144,   0],
#          [255,  68,   0],
#          ...,
#          [255,  52,   0],
#          [227,   0,   0],
#          [255,  36,   0]],
#
#         [[255,  20,   0],
#          [255,  32,   0],
#          [255,   4,   0],
#          ...,
#          [222,   0,   0],
#          [213,   0,   0],
#          [255,  80,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1022.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[250,   0,   0],
#          [255,  44,   0],
#          [255,  16,   0],
#          ...,
#          [255,  76,   0],
#          [255,   4,   0],
#          [250,   0,   0]],
#
#         [[255,   8,   0],
#          [254,   0,   0],
#          [250,   0,   0],
#          ...,
#          [255,  32,   0],
#          [241,   0,   0],
#          [255,  16,   0]],
#
#         [[255,   4,   0],
#          [232,   0,   0],
#          [255,  36,   0],
#          ...,
#          [255,  56,   0],
#          [255,  80,   0],
#          [227,   0,   0]],
#
#         ...,
#
#         [[255,   8,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  84,   0],
#          [255,  40,   0],
#          [255,   0,   0]],
#
#         [[255,   0,   0],
#          [255,   4,   0],
#          [255,  36,   0],
#          ...,
#          [255,  32,   0],
#          [255,   0,   0],
#          [254,   0,   0]],
#
#         [[255,  52,   0],
#          [255,   0,   0],
#          [255,  84,   0],
#          ...,
#          [255, 104,   0],
#          [254,   0,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1023.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   0,   0],
#          [255,   0,   0],
#          [255,   8,   0],
#          ...,
#          [255,   0,   0],
#          [255,  40,   0],
#          [255,   4,   0]],
#
#         [[222,   0,   0],
#          [218,   0,   0],
#          [255,   4,   0],
#          ...,
#          [250,   0,   0],
#          [241,   0,   0],
#          [255,  72,   0]],
#
#         [[209,   0,   0],
#          [195,   0,   0],
#          [255,  24,   0],
#          ...,
#          [255,  88,   0],
#          [255,   0,   0],
#          [227,   0,   0]],
#
#         ...,
#
#         [[255,   0,   0],
#          [255,  52,   0],
#          [255,   0,   0],
#          ...,
#          [232,   0,   0],
#          [250,   0,   0],
#          [154,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  20,   0],
#          [255,  72,   0],
#          ...,
#          [255,  12,   0],
#          [255,  56,   0],
#          [255, 104,   0]],
#
#         [[232,   0,   0],
#          [255,  52,   0],
#          [255,  72,   0],
#          ...,
#          [245,   0,   0],
#          [255,  68,   0],
#          [255,  40,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1024.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  12,   0],
#          [255,  40,   0],
#          [232,   0,   0],
#          ...,
#          [241,   0,   0],
#          [232,   0,   0],
#          [255,  36,   0]],
#
#         [[255,  76,   0],
#          [255,   0,   0],
#          [255,  92,   0],
#          ...,
#          [255,  44,   0],
#          [218,   0,   0],
#          [255,   8,   0]],
#
#         [[255, 132,   0],
#          [141,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  28,   0],
#          [254,   0,   0],
#          [245,   0,   0]],
#
#         ...,
#
#         [[255, 108,   0],
#          [255,  36,   0],
#          [255,  68,   0],
#          ...,
#          [255,   4,   0],
#          [254,   0,   0],
#          [255,  24,   0]],
#
#         [[232,   0,   0],
#          [255,  60,   0],
#          [255,   4,   0],
#          ...,
#          [232,   0,   0],
#          [168,   0,   0],
#          [255,  68,   0]],
#
#         [[255,   8,   0],
#          [255,  12,   0],
#          [255,  72,   0],
#          ...,
#          [254,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1025.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   0,   0],
#          [255,  20,   0],
#          [254,   0,   0],
#          ...,
#          [255,   0,   0],
#          [195,   0,   0],
#          [255,  52,   0]],
#
#         [[255,  12,   0],
#          [255,  68,   0],
#          [255,  92,   0],
#          ...,
#          [236,   0,   0],
#          [255,   0,   0],
#          [172,   0,   0]],
#
#         [[255,   8,   0],
#          [255,   0,   0],
#          [222,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,   8,   0],
#          [255,  28,   0]],
#
#         ...,
#
#         [[255,  48,   0],
#          [159,   0,   0],
#          [168,   0,   0],
#          ...,
#          [209,   0,   0],
#          [255,  12,   0],
#          [232,   0,   0]],
#
#         [[255,  44,   0],
#          [255,  16,   0],
#          [255,  12,   0],
#          ...,
#          [182,   0,   0],
#          [255,   0,   0],
#          [195,   0,   0]],
#
#         [[227,   0,   0],
#          [218,   0,   0],
#          [255,  36,   0],
#          ...,
#          [250,   0,   0],
#          [255,  88,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1026.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  16,   0],
#          [255,  56,   0],
#          [255,  84,   0],
#          ...,
#          [255,   0,   0],
#          [255,  12,   0],
#          [255,  60,   0]],
#
#         [[245,   0,   0],
#          [255,  28,   0],
#          [255,  12,   0],
#          ...,
#          [255,  24,   0],
#          [204,   0,   0],
#          [250,   0,   0]],
#
#         [[227,   0,   0],
#          [255,  56,   0],
#          [255,  60,   0],
#          ...,
#          [255,  12,   0],
#          [255,   0,   0],
#          [255,  16,   0]],
#
#         ...,
#
#         [[255,   0,   0],
#          [255,   0,   0],
#          [255,  76,   0],
#          ...,
#          [255,   8,   0],
#          [232,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  92,   0],
#          [236,   0,   0],
#          [255,  60,   0],
#          ...,
#          [255,  36,   0],
#          [241,   0,   0],
#          [236,   0,   0]],
#
#         [[255,  56,   0],
#          [255,  36,   0],
#          [255,  64,   0],
#          ...,
#          [255,  52,   0],
#          [255,   8,   0],
#          [255,   4,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1027.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[241,   0,   0],
#          [195,   0,   0],
#          [255,   4,   0],
#          ...,
#          [213,   0,   0],
#          [255,  68,   0],
#          [255,  48,   0]],
#
#         [[255,  20,   0],
#          [255,  24,   0],
#          [255,  28,   0],
#          ...,
#          [255,  40,   0],
#          [236,   0,   0],
#          [255,  76,   0]],
#
#         [[241,   0,   0],
#          [255,  16,   0],
#          [236,   0,   0],
#          ...,
#          [232,   0,   0],
#          [245,   0,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[255,  48,   0],
#          [227,   0,   0],
#          [254,   0,   0],
#          ...,
#          [255,  44,   0],
#          [254,   0,   0],
#          [227,   0,   0]],
#
#         [[255,  20,   0],
#          [255,  64,   0],
#          [255,   0,   0],
#          ...,
#          [255,  24,   0],
#          [255,  28,   0],
#          [204,   0,   0]],
#
#         [[255,  76,   0],
#          [255,  20,   0],
#          [255,  20,   0],
#          ...,
#          [255,   0,   0],
#          [255,  40,   0],
#          [255,  20,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1028.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[222,   0,   0],
#          [255,   0,   0],
#          [255,  48,   0],
#          ...,
#          [255,  64,   0],
#          [250,   0,   0],
#          [255,   8,   0]],
#
#         [[255,   4,   0],
#          [250,   0,   0],
#          [154,   0,   0],
#          ...,
#          [209,   0,   0],
#          [227,   0,   0],
#          [218,   0,   0]],
#
#         [[213,   0,   0],
#          [255,  60,   0],
#          [255,  12,   0],
#          ...,
#          [255,   4,   0],
#          [255,  36,   0],
#          [255,  56,   0]],
#
#         ...,
#
#         [[255,  36,   0],
#          [255,  52,   0],
#          [254,   0,   0],
#          ...,
#          [255,   8,   0],
#          [255,  72,   0],
#          [255,   8,   0]],
#
#         [[255,  16,   0],
#          [255,  16,   0],
#          [255,  44,   0],
#          ...,
#          [245,   0,   0],
#          [227,   0,   0],
#          [222,   0,   0]],
#
#         [[218,   0,   0],
#          [255,  60,   0],
#          [250,   0,   0],
#          ...,
#          [255,   0,   0],
#          [250,   0,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1029.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[254,   0,   0],
#          [255,   0,   0],
#          [241,   0,   0],
#          ...,
#          [255,  60,   0],
#          [255,   8,   0],
#          [241,   0,   0]],
#
#         [[213,   0,   0],
#          [255,  20,   0],
#          [182,   0,   0],
#          ...,
#          [255,  44,   0],
#          [255,  16,   0],
#          [255,  48,   0]],
#
#         [[245,   0,   0],
#          [255,  24,   0],
#          [255,  76,   0],
#          ...,
#          [218,   0,   0],
#          [255,  40,   0],
#          [255,  24,   0]],
#
#         ...,
#
#         [[250,   0,   0],
#          [255,   0,   0],
#          [255,  52,   0],
#          ...,
#          [255,   8,   0],
#          [255, 108,   0],
#          [255,  28,   0]],
#
#         [[255,   0,   0],
#          [255, 124,   0],
#          [255,   4,   0],
#          ...,
#          [255,  40,   0],
#          [255,  44,   0],
#          [255,  12,   0]],
#
#         [[209,   0,   0],
#          [255,  56,   0],
#          [245,   0,   0],
#          ...,
#          [250,   0,   0],
#          [255,  80,   0],
#          [255,  36,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1030.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   4,   0],
#          [255,   0,   0],
#          [255,  64,   0],
#          ...,
#          [255,  24,   0],
#          [255,  56,   0],
#          [250,   0,   0]],
#
#         [[195,   0,   0],
#          [236,   0,   0],
#          [255,  24,   0],
#          ...,
#          [255,   0,   0],
#          [218,   0,   0],
#          [255,   0,   0]],
#
#         [[241,   0,   0],
#          [255,  84,   0],
#          [255,  12,   0],
#          ...,
#          [255,   0,   0],
#          [255,  60,   0],
#          [186,   0,   0]],
#
#         ...,
#
#         [[255,  24,   0],
#          [255, 128,   0],
#          [255,  36,   0],
#          ...,
#          [255,  64,   0],
#          [250,   0,   0],
#          [255,  64,   0]],
#
#         [[255,   8,   0],
#          [245,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  12,   0],
#          [255,  52,   0],
#          [255,   0,   0]],
#
#         [[255,  16,   0],
#          [255,  64,   0],
#          [255, 116,   0],
#          ...,
#          [255,  20,   0],
#          [255,  44,   0],
#          [227,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1031.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  68,   0],
#          [255,   0,   0],
#          [255,  80,   0],
#          ...,
#          [255,  32,   0],
#          [255,  32,   0],
#          [255,  12,   0]],
#
#         [[255,  48,   0],
#          [255,   0,   0],
#          [255,  56,   0],
#          ...,
#          [255,   0,   0],
#          [245,   0,   0],
#          [222,   0,   0]],
#
#         [[191,   0,   0],
#          [255,   0,   0],
#          [255,   4,   0],
#          ...,
#          [255,  24,   0],
#          [255,   0,   0],
#          [245,   0,   0]],
#
#         ...,
#
#         [[255,  64,   0],
#          [255,  72,   0],
#          [245,   0,   0],
#          ...,
#          [255,   0,   0],
#          [255,  40,   0],
#          [255,   0,   0]],
#
#         [[255,  28,   0],
#          [255,  16,   0],
#          [255,   8,   0],
#          ...,
#          [255,  36,   0],
#          [255,   4,   0],
#          [255,  56,   0]],
#
#         [[255,  28,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,  40,   0],
#          [255,   0,   0],
#          [236,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1032.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255, 148,   0],
#          [255,  32,   0],
#          [255,  16,   0],
#          ...,
#          [255,  40,   0],
#          [255,  60,   0],
#          [255,  28,   0]],
#
#         [[236,   0,   0],
#          [255,  16,   0],
#          [255,  36,   0],
#          ...,
#          [255,   0,   0],
#          [255,  80,   0],
#          [255,  36,   0]],
#
#         [[255,  64,   0],
#          [255,  92,   0],
#          [163,   0,   0],
#          ...,
#          [172,   0,   0],
#          [255,   0,   0],
#          [255,  76,   0]],
#
#         ...,
#
#         [[255,  16,   0],
#          [255,  32,   0],
#          [255,   0,   0],
#          ...,
#          [154,   0,   0],
#          [250,   0,   0],
#          [255,  36,   0]],
#
#         [[255,  16,   0],
#          [255,  28,   0],
#          [255,  36,   0],
#          ...,
#          [255,  76,   0],
#          [255,   4,   0],
#          [255,   0,   0]],
#
#         [[255,  24,   0],
#          [227,   0,   0],
#          [255,  44,   0],
#          ...,
#          [255,   0,   0],
#          [213,   0,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1033.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   4,   0],
#          [255,  60,   0],
#          [255,  16,   0],
#          ...,
#          [255,  28,   0],
#          [232,   0,   0],
#          [255,  36,   0]],
#
#         [[255,  20,   0],
#          [255,  84,   0],
#          [195,   0,   0],
#          ...,
#          [255,  84,   0],
#          [255,  40,   0],
#          [204,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  48,   0],
#          [255,   0,   0],
#          ...,
#          [255, 116,   0],
#          [255,  56,   0],
#          [255,  16,   0]],
#
#         ...,
#
#         [[255,  16,   0],
#          [191,   0,   0],
#          [255,   4,   0],
#          ...,
#          [255,  28,   0],
#          [255,  44,   0],
#          [255,   8,   0]],
#
#         [[222,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [232,   0,   0],
#          [241,   0,   0],
#          [255,  44,   0]],
#
#         [[255,  32,   0],
#          [255,  44,   0],
#          [182,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,  48,   0],
#          [209,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1034.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  44,   0],
#          [213,   0,   0],
#          [255, 104,   0],
#          ...,
#          [255,  84,   0],
#          [255,  96,   0],
#          [255,   8,   0]],
#
#         [[236,   0,   0],
#          [255,   8,   0],
#          [255,   4,   0],
#          ...,
#          [255,   8,   0],
#          [255,  24,   0],
#          [255,  64,   0]],
#
#         [[255,   0,   0],
#          [255,  80,   0],
#          [255,  92,   0],
#          ...,
#          [255,  48,   0],
#          [255,  60,   0],
#          [255,  88,   0]],
#
#         ...,
#
#         [[168,   0,   0],
#          [255,   0,   0],
#          [250,   0,   0],
#          ...,
#          [255, 116,   0],
#          [241,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  68,   0],
#          [255,  20,   0],
#          [209,   0,   0],
#          ...,
#          [255,  28,   0],
#          [236,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  52,   0],
#          [255,  36,   0],
#          [255,  12,   0],
#          ...,
#          [255,  60,   0],
#          [232,   0,   0],
#          [255, 100,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1035.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  44,   0],
#          [213,   0,   0],
#          [255, 104,   0],
#          ...,
#          [255,  84,   0],
#          [255,  96,   0],
#          [255,   8,   0]],
#
#         [[236,   0,   0],
#          [255,   8,   0],
#          [255,   4,   0],
#          ...,
#          [255,   8,   0],
#          [255,  24,   0],
#          [255,  64,   0]],
#
#         [[255,   0,   0],
#          [255,  80,   0],
#          [255,  92,   0],
#          ...,
#          [255,  48,   0],
#          [255,  60,   0],
#          [255,  88,   0]],
#
#         ...,
#
#         [[168,   0,   0],
#          [255,   0,   0],
#          [250,   0,   0],
#          ...,
#          [255, 116,   0],
#          [241,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  68,   0],
#          [255,  20,   0],
#          [209,   0,   0],
#          ...,
#          [255,  28,   0],
#          [236,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  52,   0],
#          [255,  36,   0],
#          [255,  12,   0],
#          ...,
#          [255,  60,   0],
#          [232,   0,   0],
#          [255, 100,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1036.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  64,   0],
#          [255,  52,   0],
#          [255,   0,   0],
#          ...,
#          [255,  76,   0],
#          [255,  12,   0],
#          [255,  68,   0]],
#
#         [[255,  48,   0],
#          [255,   0,   0],
#          [255,  68,   0],
#          ...,
#          [255,  92,   0],
#          [255,  56,   0],
#          [255,  16,   0]],
#
#         [[255,  24,   0],
#          [255,  48,   0],
#          [255,  24,   0],
#          ...,
#          [255,  12,   0],
#          [255, 144,   0],
#          [255,  40,   0]],
#
#         ...,
#
#         [[255,  44,   0],
#          [255,  88,   0],
#          [236,   0,   0],
#          ...,
#          [191,   0,   0],
#          [255,  76,   0],
#          [255,  36,   0]],
#
#         [[255,  40,   0],
#          [255,  52,   0],
#          [255,   0,   0],
#          ...,
#          [241,   0,   0],
#          [255,  72,   0],
#          [255,  72,   0]],
#
#         [[255,  12,   0],
#          [232,   0,   0],
#          [245,   0,   0],
#          ...,
#          [255,  48,   0],
#          [255,  80,   0],
#          [255,  32,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1037.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  28,   0],
# ...
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [255,   0,   0],
#          [232,   0,   0],
#          [232,   0,   0]],
#
#         [[255,  92,   0],
#          [186,   0,   0],
#          [232,   0,   0],
#          ...,
#          [255,  92,   0],
#          [255,   8,   0],
#          [200,   0,   0]],
#
#         ...,
#
#         [[195,   0,   0],
#          [255,  32,   0],
#          [241,   0,   0],
#          ...,
#          [127,   0,   0],
#          [255,  80,   0],
#          [255, 104,   0]],
#
#         [[255,  28,   0],
#          [255,  32,   0],
#          [255,  40,   0],
#          ...,
#          [255,  36,   0],
#          [255,   0,   0],
#          [255,  64,   0]],
#
#         [[255,  36,   0],
#          [255,   8,   0],
#          [255,   4,   0],
#          ...,
#          [255,  12,   0],
#          [255, 100,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1107.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  48,   0],
#          [241,   0,   0],
#          [255,  32,   0],
#          ...,
#          [254,   0,   0],
#          [255,  76,   0],
#          [236,   0,   0]],
#
#         [[255,  12,   0],
#          [255,   0,   0],
#          [255,  36,   0],
#          ...,
#          [255,   0,   0],
#          [255,   8,   0],
#          [191,   0,   0]],
#
#         [[255,  44,   0],
#          [255,  28,   0],
#          [255,   0,   0],
#          ...,
#          [255,  24,   0],
#          [255, 124,   0],
#          [255,  44,   0]],
#
#         ...,
#
#         [[255,   0,   0],
#          [255,  20,   0],
#          [241,   0,   0],
#          ...,
#          [255,   0,   0],
#          [255,  80,   0],
#          [255,   8,   0]],
#
#         [[245,   0,   0],
#          [255,  36,   0],
#          [255,   4,   0],
#          ...,
#          [255,  56,   0],
#          [186,   0,   0],
#          [255,  12,   0]],
#
#         [[255,  72,   0],
#          [255,  68,   0],
#          [255,  12,   0],
#          ...,
#          [255,  88,   0],
#          [255,  76,   0],
#          [255,  64,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1108.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  36,   0],
#          [255,  48,   0],
#          [255,  28,   0],
#          ...,
#          [255,   0,   0],
#          [255,  48,   0],
#          [255,  48,   0]],
#
#         [[227,   0,   0],
#          [227,   0,   0],
#          [255,  20,   0],
#          ...,
#          [213,   0,   0],
#          [255,  76,   0],
#          [200,   0,   0]],
#
#         [[255,  16,   0],
#          [255,  12,   0],
#          [255,  80,   0],
#          ...,
#          [255,  48,   0],
#          [255,  44,   0],
#          [255,  24,   0]],
#
#         ...,
#
#         [[255,  48,   0],
#          [255,  12,   0],
#          [254,   0,   0],
#          ...,
#          [250,   0,   0],
#          [232,   0,   0],
#          [255,   0,   0]],
#
#         [[186,   0,   0],
#          [255,   0,   0],
#          [255,  24,   0],
#          ...,
#          [255,   8,   0],
#          [255,  68,   0],
#          [255,  36,   0]],
#
#         [[255,  80,   0],
#          [177,   0,   0],
#          [255,  56,   0],
#          ...,
#          [255,  20,   0],
#          [255,  40,   0],
#          [236,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1109.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  12,   0],
#          [255,  44,   0],
#          [255,  48,   0],
#          ...,
#          [255,  56,   0],
#          [255,  56,   0],
#          [255,  44,   0]],
#
#         [[255,   4,   0],
#          [255,  48,   0],
#          [255,  64,   0],
#          ...,
#          [255,   0,   0],
#          [255,  60,   0],
#          [255,   4,   0]],
#
#         [[255,  48,   0],
#          [250,   0,   0],
#          [255,  48,   0],
#          ...,
#          [255,   0,   0],
#          [255,  44,   0],
#          [255,   0,   0]],
#
#         ...,
#
#         [[255,   4,   0],
#          [255,  80,   0],
#          [255,  60,   0],
#          ...,
#          [255,  72,   0],
#          [255, 120,   0],
#          [255,  32,   0]],
#
#         [[255, 100,   0],
#          [255,   0,   0],
#          [204,   0,   0],
#          ...,
#          [255,  68,   0],
#          [255,  60,   0],
#          [255,  24,   0]],
#
#         [[255,   4,   0],
#          [204,   0,   0],
#          [255,   8,   0],
#          ...,
#          [172,   0,   0],
#          [255,  60,   0],
#          [255,   4,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1110.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   0,   0],
#          [255,  20,   0],
#          [254,   0,   0],
#          ...,
#          [255,   0,   0],
#          [195,   0,   0],
#          [255,  52,   0]],
#
#         [[255,  12,   0],
#          [255,  68,   0],
#          [255,  92,   0],
#          ...,
#          [236,   0,   0],
#          [255,   0,   0],
#          [172,   0,   0]],
#
#         [[255,   8,   0],
#          [255,   0,   0],
#          [222,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,   8,   0],
#          [255,  28,   0]],
#
#         ...,
#
#         [[255,  48,   0],
#          [159,   0,   0],
#          [168,   0,   0],
#          ...,
#          [209,   0,   0],
#          [255,  12,   0],
#          [232,   0,   0]],
#
#         [[255,  44,   0],
#          [255,  16,   0],
#          [255,  12,   0],
#          ...,
#          [182,   0,   0],
#          [255,   0,   0],
#          [195,   0,   0]],
#
#         [[227,   0,   0],
#          [218,   0,   0],
#          [255,  36,   0],
#          ...,
#          [250,   0,   0],
#          [255,  88,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1111.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[250,   0,   0],
#          [250,   0,   0],
#          [255,  60,   0],
#          ...,
#          [255,   0,   0],
#          [227,   0,   0],
#          [255,   0,   0]],
#
#         [[255,  76,   0],
#          [241,   0,   0],
#          [254,   0,   0],
#          ...,
#          [255,  16,   0],
#          [255,  56,   0],
#          [255,   0,   0]],
#
#         [[255,  68,   0],
#          [255,  40,   0],
#          [232,   0,   0],
#          ...,
#          [255,  48,   0],
#          [241,   0,   0],
#          [255,  28,   0]],
#
#         ...,
#
#         [[255,  40,   0],
#          [255,   4,   0],
#          [255,  68,   0],
#          ...,
#          [255,  56,   0],
#          [255,  12,   0],
#          [255,  20,   0]],
#
#         [[255,  68,   0],
#          [255,  28,   0],
#          [255,  80,   0],
#          ...,
#          [255,  24,   0],
#          [255,  68,   0],
#          [254,   0,   0]],
#
#         [[255,  20,   0],
#          [255,  92,   0],
#          [255, 124,   0],
#          ...,
#          [255,  20,   0],
#          [255,  44,   0],
#          [255,  72,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1112.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255, 112,   0],
#          [254,   0,   0],
#          [255,  28,   0],
#          ...,
#          [227,   0,   0],
#          [255,   8,   0],
#          [255,  32,   0]],
#
#         [[255,   0,   0],
#          [177,   0,   0],
#          [255,  68,   0],
#          ...,
#          [254,   0,   0],
#          [232,   0,   0],
#          [204,   0,   0]],
#
#         [[255,   4,   0],
#          [255,  40,   0],
#          [255,   0,   0],
#          ...,
#          [255,   0,   0],
#          [255,   0,   0],
#          [255,   4,   0]],
#
#         ...,
#
#         [[255,  52,   0],
#          [255,   0,   0],
#          [245,   0,   0],
#          ...,
#          [255,  32,   0],
#          [255, 104,   0],
#          [255,  28,   0]],
#
#         [[255,  56,   0],
#          [236,   0,   0],
#          [255,  36,   0],
#          ...,
#          [250,   0,   0],
#          [255,  16,   0],
#          [200,   0,   0]],
#
#         [[255,  44,   0],
#          [255,  52,   0],
#          [255,  32,   0],
#          ...,
#          [255,  28,   0],
#          [255,  84,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1113.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   4,   0],
#          [255,  60,   0],
#          [255,  16,   0],
#          ...,
#          [255,  28,   0],
#          [232,   0,   0],
#          [255,  36,   0]],
#
#         [[255,  20,   0],
#          [255,  84,   0],
#          [195,   0,   0],
#          ...,
#          [255,  84,   0],
#          [255,  40,   0],
#          [204,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  48,   0],
#          [255,   0,   0],
#          ...,
#          [255, 116,   0],
#          [255,  56,   0],
#          [255,  16,   0]],
#
#         ...,
#
#         [[255,  16,   0],
#          [191,   0,   0],
#          [255,   4,   0],
#          ...,
#          [255,  28,   0],
#          [255,  44,   0],
#          [255,   8,   0]],
#
#         [[222,   0,   0],
#          [255,   0,   0],
#          [255,   0,   0],
#          ...,
#          [232,   0,   0],
#          [241,   0,   0],
#          [255,  44,   0]],
#
#         [[255,  32,   0],
#          [255,  44,   0],
#          [182,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,  48,   0],
#          [209,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1114.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,   8,   0],
#          [255,  84,   0],
#          [255,  20,   0],
#          ...,
#          [255,   0,   0],
#          [255,  36,   0],
#          [255,  12,   0]],
#
#         [[255,  20,   0],
#          [255,  44,   0],
#          [255,  24,   0],
#          ...,
#          [255,  16,   0],
#          [255,   0,   0],
#          [255,  48,   0]],
#
#         [[255,  64,   0],
#          [255,  68,   0],
#          [236,   0,   0],
#          ...,
#          [255,  16,   0],
#          [255,  60,   0],
#          [255,  24,   0]],
#
#         ...,
#
#         [[255,  68,   0],
#          [250,   0,   0],
#          [255,  68,   0],
#          ...,
#          [255,   0,   0],
#          [218,   0,   0],
#          [255,  72,   0]],
#
#         [[255,  80,   0],
#          [255,   0,   0],
#          [218,   0,   0],
#          ...,
#          [236,   0,   0],
#          [255,  28,   0],
#          [255,  52,   0]],
#
#         [[255,  16,   0],
#          [255,  32,   0],
#          [255,  52,   0],
#          ...,
#          [255,  80,   0],
#          [255,  20,   0],
#          [255,  52,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1115.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[255,  24,   0],
#          [255,  16,   0],
#          [255,   0,   0],
#          ...,
#          [255,  28,   0],
#          [255,  16,   0],
#          [218,   0,   0]],
#
#         [[168,   0,   0],
#          [255,  28,   0],
#          [255,   0,   0],
#          ...,
#          [255,  52,   0],
#          [213,   0,   0],
#          [255,  16,   0]],
#
#         [[255,  16,   0],
#          [255, 124,   0],
#          [254,   0,   0],
#          ...,
#          [255,  56,   0],
#          [255,  28,   0],
#          [245,   0,   0]],
#
#         ...,
#
#         [[255,   8,   0],
#          [255,  36,   0],
#          [255,  44,   0],
#          ...,
#          [255,  12,   0],
#          [255,  40,   0],
#          [254,   0,   0]],
#
#         [[255,   0,   0],
#          [255,  56,   0],
#          [255,   0,   0],
#          ...,
#          [255,  52,   0],
#          [255,   0,   0],
#          [255,  32,   0]],
#
#         [[255,  64,   0],
#          [255,  60,   0],
#          [255,  56,   0],
#          ...,
#          [255,  36,   0],
#          [250,   0,   0],
#          [255,  88,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1116.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'ER'}
#  obb: None
#  orig_img: array([[[236,   0,   0],
#          [254,   0,   0],
#          [255,  24,   0],
#          ...,
#          [255,   8,   0],
#          [255,  24,   0],
#          [255,  56,   0]],
#
#         [[227,   0,   0],
#          [241,   0,   0],
#          [255,  44,   0],
#          ...,
#          [241,   0,   0],
#          [255,  76,   0],
#          [255,  48,   0]],
#
#         [[255,  68,   0],
#          [255, 104,   0],
#          [222,   0,   0],
#          ...,
#          [222,   0,   0],
#          [255,  96,   0],
#          [255,   4,   0]],
#
#         ...,
#
#         [[255,  28,   0],
#          [255, 108,   0],
#          [255,  60,   0],
#          ...,
#          [255,  20,   0],
#          [255,  44,   0],
#          [255,  24,   0]],
#
#         [[255,  20,   0],
#          [236,   0,   0],
#          [255,   4,   0],
#          ...,
#          [255,  32,   0],
#          [255,  48,   0],
#          [213,   0,   0]],
#
#         [[227,   0,   0],
#          [255,  32,   0],
#          [255,  40,   0],
#          ...,
#          [222,   0,   0],
#          [236,   0,   0],
#          [255,   0,   0]]], dtype=uint8)
#  orig_shape: (288, 512)
#  path: 'datasets/test_noise/images/1117.png'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 0.5646986620766776, 'inference': 1.754394599369594, 'postprocess': 0.5223644631249564}]

# %%
#Now lets look at boxes and keypoints for the first image
print(results[0].boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8357], device='cuda:0')
# data: tensor([[256.0000, 145.0000, 288.0000, 176.0000,   0.8357,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (288, 512)
# shape: torch.Size([1, 6])
# xywh: tensor([[272.0000, 160.5000,  32.0000,  31.0000]], device='cuda:0')
# xywhn: tensor([[0.5312, 0.5573, 0.0625, 0.1076]], device='cuda:0')
# xyxy: tensor([[256., 145., 288., 176.]], device='cuda:0')
# xyxyn: tensor([[0.5000, 0.5035, 0.5625, 0.6111]], device='cuda:0')

# %%
#The above shows several options for boxes. The xyxyn format gives [xmin,ymin,xmax,ymax] of the bounding box
#normalized to 1. This is what we should use so we can upscale the box to the 2048 x 1152 image

results[0].boxes.xyxyn.cpu().numpy()
# Out:
# array([[        0.5,     0.50347,      0.5625,     0.61111]], dtype=float32)

# %%
#It's possible that there can be more than one bounding box per image, let's check if any images identified more than
#one track. If they do, any additionalbounding boxes beyond the first would be a false positive

for i,res in enumerate(results):
    if len(res.boxes.xyxyn) > 1:
        print(i)

# %% [markdown]
# ### We've now looped through and see that there is one box per image, meaning YOLO identified our objects perfectly. Now let's look at the keypoints

# %%
results[0].keypoints
# Out:
# ultralytics.engine.results.Keypoints object with attributes:
#
# conf: None
# data: tensor([[[263.8941, 167.5229],
#          [266.8430, 166.1176],
#          [269.5149, 164.2394],
#          [271.4712, 161.5618],
#          [273.1130, 158.3103],
#          [275.0742, 155.8278],
#          [278.2883, 154.3971]]], device='cuda:0')
# has_visible: False
# orig_shape: (288, 512)
# shape: torch.Size([1, 7, 2])
# xy: tensor([[[263.8941, 167.5229],
#          [266.8430, 166.1176],
#          [269.5149, 164.2394],
#          [271.4712, 161.5618],
#          [273.1130, 158.3103],
#          [275.0742, 155.8278],
#          [278.2883, 154.3971]]], device='cuda:0')
# xyn: tensor([[[0.5154, 0.5817],
#          [0.5212, 0.5768],
#          [0.5264, 0.5703],
#          [0.5302, 0.5610],
#          [0.5334, 0.5497],
#          [0.5373, 0.5411],
#          [0.5435, 0.5361]]], device='cuda:0')

# %%
#the .xyn field contains the normalized keypoint coordinates so lets use these so we can scale them up to 2048 x 1152
#Let's quickly check if all 7 keypoints are found in each image

for i,res in enumerate(results):
    if len(res.keypoints.xyn[0]) != 7:
        print(i)

# %% [markdown]
# # Lets aggregate our keypoint and bounding box predictions into a dataframe so we can quantitatively compare them with truth

# %%
### The columns of interest are 'class_index', 'xBB', 'yBB', 'width',
### 'height', 'p0x', 'p0y', 'p1x', 'p1y', 'p2x', 'p2y', 'p3x', 'p3y', 'p4x',
### 'p4y', 'p5x', 'p5y', 'p6x', 'p6y'
### We need to convert these back to the aspect ratio of the camera

xcols = ['xBB', 'width','p0x', 'p1x', 'p2x', 'p3x', 'p4x', 'p5x','p6x']
ycols = ['yBB', 'height','p0y', 'p1y', 'p2y', 'p3y', 'p4y', 'p5y','p6y']

xdim = 2048
ydim = 1152

for col in xcols:
    df[col] = df[col]*xdim

for col in ycols:
    df[col] = df[col]*ydim

# %% [markdown]
# ### Our bounding box dimensions are [xmin,xmax,ymin,ymax] so lets make columns for these in our test dataframe too

# %%
'''Bounding box perimeters'''
df['xmin'] = np.round(df['xBB']-df['width']/2).astype('int')
df['xmax'] = np.round(df['xBB']+df['width']/2).astype('int')

df['ymin'] = np.round(df['yBB']-df['height']/2).astype('int')
df['ymax'] = np.round(df['yBB']+df['height']/2).astype('int')

# %% [markdown]
# ### Now let's compile the YOLO results

# %%
'''We compile results into track-indexed data but will store the frame index so we can link back
to data indexed by image frame. Since we only had one track per frame in this example, there will be a one-to-one
correspondence between frame-indexed and track-indexed data. That will not be the case in general. 
The code below handles the general case.'''

pointsPerTrack = 7 #we have 7 keypoints per track

yolo = pd.DataFrame() #YOLO results dataframe
xmin = []
xmax = []
ymin = []
ymax = []
pred = [] #class prediction, should be 0 (ER) for each event in this sample
prob = [] #class prediction confidence score between 0 and 1. 1 is most confident, 0 means the model has no idea
frameIndex = []
coords = {}

#Fill coords dictionary with lists of each keypoint
for i in range(0,pointsPerTrack):
    coords[i] = []
for i,res in enumerate(results):
    boxes = res.boxes.xyxyn.cpu().numpy() #tensor of all of the boxes converted to 4 x Nboxes numpy array
    points = res.keypoints.xyn.cpu().numpy() #tensor of all sets of key points as (1 x 2) x NkeyPointSets array 
    data = res.boxes.data.cpu().numpy() #to get class prediction and class confidence score
    for datum, box, point in zip(data,boxes,points): #loop through all boxes and sets of key points in frame i
        frameIndex.append(i) #frame index
        xmin.append(box[0]*2048)
        ymin.append(box[1]*1152)
        xmax.append(box[2]*2048)
        ymax.append(box[3]*1152)
        pred.append(datum[5])
        prob.append(datum[4])
        #grab each of the 7 key points to put into the coords[j] list these are still normalized
        for j,p in enumerate(point):
            coords[j].append(p)

# %%
'''Now we populate the yolo results dataframe'''
yolo['frame'] = frameIndex #frame number
yolo['xmin'] = xmin
yolo['xmax'] = xmax
yolo['ymin'] = ymin
yolo['ymax'] = ymax
yolo['pred'] = pred
yolo['prob'] = prob
for i in range(0,pointsPerTrack):
    yolo['p%s'%(i)] = coords[i]

# %%
'''Now lets change the pj"s to pjx and pjy and also convert to resolution of the camera'''
# Initialize an empty dictionary to hold the new columns
new_columns = {}

# Iterate over each of the keypoint columns in the DataFrame
for col in yolo.columns[int(-1*pointsPerTrack):]:
    # Extract x and y components from each column
    yolo[[f'{col}x', f'{col}y']] = pd.DataFrame(yolo[col].tolist(), index=yolo.index)
    # Drop the original column
    yolo.drop(columns=[col], inplace=True)
    
'''Scale pjx and pjy to aspect ratio of images'''
for i in range(0,pointsPerTrack):
    yolo['p%sx'%(i)] *= 2048
    yolo['p%sy'%(i)] *= 1152

# %%
yolo
# Out:
#      frame    xmin    xmax        ymin        ymax  pred      prob
# 0        0   476.0   608.0  723.999985  856.000031   0.0  0.767477  \
# 1        1  1040.0  1196.0  515.999989  615.999985   0.0  0.781239
# 2        2   588.0   712.0  144.000000  283.999998   0.0  0.709186
# 3        3   844.0  1016.0  279.999996  392.000015   0.0  0.764482
# 4        4   860.0  1028.0  203.999994  356.000015   0.0  0.773963
# ..     ...     ...     ...         ...         ...   ...       ...
# 107    107   204.0   348.0  464.000015  567.999996   0.0  0.712902
# 108    108   148.0   304.0  736.000008  847.999992   0.0  0.665492
# 109    109   684.0   832.0  752.000015  892.000031   0.0  0.756053
# 110    110   772.0   908.0  328.000019  420.000011   0.0  0.768627
# 111    111  1192.0  1328.0  500.000015  640.000031   0.0  0.723110
#
#              p0x         p0y          p1x  ...          p2x         p2y
# 0     510.727386  815.828064   518.355042  ...   526.838806  801.558167  \
# 1    1077.564575  565.492615  1089.589722  ...  1100.385498  563.783325
# 2     635.204407  230.236176   644.819092  ...   653.623779  227.218536
# 3     877.192932  328.856873   891.859009  ...   905.430115  331.307465
# 4     900.665649  306.001007   914.717468  ...   926.900146  295.435669
# ..           ...         ...          ...  ...          ...         ...
# 107   245.478912  527.635315   254.536072  ...   263.361176  522.618835
# 108   188.738586  805.788330   200.584244  ...   211.390732  792.066406
# 109   721.843933  843.655762   733.228027  ...   744.212097  833.772095
# 110   803.669189  379.290283   813.931030  ...   823.989868  375.969360
# 111  1230.158325  539.822144  1239.838623  ...  1247.732300  554.722229
#
#              p3x         p3y          p4x         p4y          p5x
# 0     534.195435  790.911987   542.211792  780.183960   552.242371  \
# 1    1111.234741  563.605835  1122.599243  564.074219  1134.593384
# 2     658.786987  222.096268   662.716797  214.845352   665.295532
# 3     919.230591  333.733582   933.848511  335.848480   948.801208
# 4     938.247070  286.412872   950.057678  277.077087   962.295105
# ..           ...         ...          ...         ...          ...
# 107   271.006134  518.360535   279.599182  513.635559   288.817841
# 108   222.943634  788.354309   234.304382  787.597900   247.004196
# 109   753.586487  824.925659   762.591125  814.321411   772.208679
# 110   834.178162  373.702484   844.499207  372.428864   855.257568
# 111  1253.530029  565.215393  1259.463135  575.978516  1268.139893
#
#             p5y          p6x         p6y
# 0    771.807312   563.474060  766.103210
# 1    566.808472  1145.840210  567.070862
# 2    209.731049   671.104126  206.718216
# 3    338.940430   962.699768  339.500610
# 4    270.251923   975.356445  262.827881
# ..          ...          ...         ...
# 107  509.777985   297.480835  506.111511
# 108  793.844421   259.422333  794.538757
# 109  805.285217   783.248962  797.922852
# 110  372.976044   865.089355  371.774872
# 111  586.458618  1275.720215  593.921265
#
# [112 rows x 21 columns]

# %% [markdown]
# ### Let's plot an example output

# %%
df['vignetted_q'].apply(lambda x: len(x))
# Out:
# 0      4807
# 1      5419
# 2      5859
# 3      6710
# 4      6008
#        ...
# 107    3396
# 108    2955
# 109    5992
# 110    4401
# 111    4485
# Name: vignetted_q, Length: 112, dtype: int64

# %%
#Assumes test dataframe is called df and yolo results are called yolo
def plot_output(i):
    tmp = df.iloc[i]
    tmpyolo = yolo.iloc[i]
    '''Use vignetted_q with noise, otherwise q'''
    im = np.histogram2d(tmp['x'],tmp['y'],weights=tmp['vignetted_q'],bins=(2048,1152),range=((0,2048),(0,1152)))[0].T
    plt.imshow(im,cmap='viridis')
    
    #Truth bounding box in white
    plt.hlines(tmp['ymin'],tmp['xmin'],tmp['xmax'],color='w',lw=2)
    plt.hlines(tmp['ymax'],tmp['xmin'],tmp['xmax'],color='w',lw=2)
    plt.vlines(tmp['xmin'],tmp['ymin'],tmp['ymax'],color='w',lw=2)
    plt.vlines(tmp['xmax'],tmp['ymin'],tmp['ymax'],color='w',lw=2)
    
    #Predicted bounding box in cyan
    plt.hlines(tmpyolo['ymin'],tmpyolo['xmin'],tmpyolo['xmax'],color='cyan',lw=2)
    plt.hlines(tmpyolo['ymax'],tmpyolo['xmin'],tmpyolo['xmax'],color='cyan',lw=2)
    plt.vlines(tmpyolo['xmin'],tmpyolo['ymin'],tmpyolo['ymax'],color='cyan',lw=2)
    plt.vlines(tmpyolo['xmax'],tmpyolo['ymin'],tmpyolo['ymax'],color='cyan',lw=2)
    
    plt.xlim(tmp['xmin']-15,tmp['xmax']+15)
    plt.ylim(tmp['ymin']-15,tmp['ymax']+15)
    
    #Truth keypoints in white, predicted keypoints in cyan
    for i in range(0,pointsPerTrack):
        if i == 0:
            plt.plot(tmp['p%sx'%(i)],tmp['p%sy'%(i)],'o',color='k')
            plt.plot(tmpyolo['p%sx'%(i)],tmpyolo['p%sy'%(i)],'o',color='y')
        else:
            plt.plot(tmp['p%sx'%(i)],tmp['p%sy'%(i)],'o',color='w')
            plt.plot(tmpyolo['p%sx'%(i)],tmpyolo['p%sy'%(i)],'o',color='cyan')
        
    plt.show()

# %%
plot_output(8)

# %%
plot_output(9)

# %% [markdown]
# # Visually most of the tracks look similar so lets quantify our performance
#
# We'll start with bounding box quantification. We use the IOU which stands for "intersection over union" metric. This metric is the ratio of the areas of the intersection to union of the truth and predicted bounding boxes. Perfect overlap is 1, no overlap is 0
#
# ![image info](./figures/IOU_def.png)

# %%
def bb_intersection_over_union(xmin1, xmax1, ymin1, ymax1, xmin2, xmax2, ymin2, ymax2):
    
    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(xmin1, xmin2)
    yA = max(ymin1, ymin2)
    xB = min(xmax1, xmax2)
    yB = min(ymax1, ymax2)
    
    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    
    # compute the area of both the prediction and ground-truth rectangles
    
    boxAArea = (xmax1 - xmin1 + 1) * (ymax1 - ymin1 + 1)
    boxBArea = (xmax2 - xmin2 + 1) * (ymax2 - ymin2 + 1)
    
    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area so we don't double count the intersection
    
    iou = interArea / (boxAArea + boxBArea - interArea)

    return iou

# %%
IOUs = []
for i in range(0,len(df)):
    tmp = df.iloc[i]
    tmpyolo = yolo.iloc[i]
    IOU = bb_intersection_over_union(tmp['xmin'], tmp['xmax'], tmp['ymin'], tmp['ymax'], 
                                     tmpyolo['xmin'], tmpyolo['xmax'], tmpyolo['ymin'], tmpyolo['ymax'])
    IOUs.append(IOU)

# %%
metrics = pd.DataFrame()
metrics['IOU'] = IOUs

# %%
# Let's visualize our IOU scores

plt.hist(metrics['IOU'])
# Out:
# (array([          1,           1,           1,           6,           8,          14,          27,          26,          18,          10]),
#  array([    0.45559,     0.50521,     0.55482,     0.60444,     0.65406,     0.70367,     0.75329,     0.80291,     0.85252,     0.90214,     0.95176]),
#  <BarContainer object of 10 artists>)

# %%
# Generally speaking our IOUs look great. Lets see what the best and worst overlapping events look like

worstIOUidx = metrics['IOU'].nsmallest(1).index.to_numpy()[0]
bestIOUidx = metrics['IOU'].nlargest(1).index.to_numpy()[0]

# %%
plot_output(worstIOUidx)

# %%
plot_output(bestIOUidx)

# %% [markdown]
# # Even the worst IOU overlap looks like a reasonable prediction!
# The light below the predicted bounding box in the worst IOU example is very faint. We could improve this if we trained on logarithmic colorscale images
#
# # Next lets assess our keypoint detection performance
# Coming up with a good metric to holistically assess keypoint assignments is important, and there's a good deal of flexibilty of how to come up with one. Genreally speaking, with ML metrics, we want something that ranges from 0 to 1 with 0 being maximally bad and 1 being maximally good. The computer vision community often uses a metric called [object keypoint similarity](https://learnopencv.com/object-keypoint-similarity/), which satisfies these criteria. We'll use a simplified version of object keypoint similarity and begin by defining the keypoint similarity of point $i$ as
# $$
# KS_{i} = \exp\left(\frac{-d_i^2}{2s^2k^2}\right),
# $$
#
# where $d_i$ is the Euclidean distance between point the truth and predicted keypoint $i$, $s$ is a scale parameter defined as the area of the truth bounding box, and $k$ is an empirically determined constant. For an image we'll compute the object keypoint similarity, $\rm OKS$, as
# $$
# \mathrm{OKS}=\frac{1}{N_\mathrm{keypoints}}\sum_{i=1}^{N_\mathrm{keypoints}}KS_i
# $$
#
# **Important, OKS is an ordered quantity. The order of the keypoints determined by YOLO is supposed to match the truth ordering. For applications where direction matters, we want OKS to be order dependent. If we don't care about direction, we can reorder the points before computing OKS in such a way that it minimizes the Euclidean distance.**

# %%
'''Define a function for order-dependents OKS between truth and measured'''
def order_dependent_OKS(truth,meas,k): #arguments are two tracks which we can think of as rows of dataframes
    distances = []
    for i in range(0,pointsPerTrack): #Loop through each point in the event
        d = np.sqrt((meas['p%sx'%(i)]-truth['p%sx'%(i)])**2+(meas['p%sy'%(i)]-truth['p%sy'%(i)])**2)
        distances.append(d)
    scale = truth['width']*truth['height'] #This is s, we'll compute truth bounding box relative to image size for this
    OKS = np.exp(-1*(np.array(distances)**2)/(2*scale**2*k**2)).sum()/pointsPerTrack
    print(OKS)
    return OKS

# %%
'''Compute OKS'''
OKSs = []
for i in range(0,len(df)):
    tmp = df.iloc[i]
    tmpyolo = yolo.iloc[i]
    OKS = order_dependent_OKS(tmp,tmpyolo,k=0.001)
    OKSs.append(OKS)
# Out:
# 0.8303589014396555
# 0.9076314573840547
# 0.6802997120032624
# 0.8045239146297035
# 0.8249745625312616
# 0.6540043294409674
# 0.8830224294244594
# 0.5208660603696115
# 0.9078623336496162
# 0.887109245088954
# 0.8953470413727731
# 0.7636528360047491
# 0.8721009079073446
# 0.7258287767457817
# 0.599776471639504
# 0.6775392539036843
# 0.8620559183870744
# 0.945783147260827
# 0.7364189801288881
# 0.8349888665336493
# 0.9332436421872641
# 0.3610770761638162
# 0.9374879943441198
# 0.7185129381367024
# 0.6441827588567609
# 0.46398141633104534
# 0.2683564062103378
# 0.914698391374419
# 0.9398692241537868
# 0.7744638830193065
# 0.8389954804156271
# 0.9449965776670967
# 0.8746423755030668
# 0.6009135656477185
# 0.9313284970241862
# 0.9646726817354276
# 0.5594489944186173
# 0.7934155395771711
# 0.8489930871402837
# 0.900683943953777
# 0.8094037480381708
# 0.9799990699159141
# 0.8363891016197668
# 0.673241332211586
# 0.7102367066813289
# 0.7864017960773537
# 0.664811754592258
# 0.6144503248618569
# 0.8846843464126376
# 0.81611071342957
# 0.8870673053314386
# 0.9066385778591849
# 0.9024574068882334
# 0.8300401854000626
# 0.4568866984682848
# 0.7513301982111882
# 0.8146126482874608
# 0.875910036885046
# 0.37712286030243847
# 0.8055138047778202
# 0.9325095386594023
# 0.9790416068248485
# 0.6971856905169073
# 0.5661217291291468
# 0.9602893400181348
# 0.8814205782133417
# 0.7724214549415175
# 0.873303439900272
# 0.8936613330413131
# 0.6360350197544958
# 0.8461673664211374
# 0.9049713699882965
# 0.8417703963429154
# 0.37719198840391294
# 0.9261497914198547
# 0.9371513754457583
# 0.9101742669106321
# 0.8757346766833203
# 0.9076486975395964
# 0.9380722181260659
# 0.781826248640398
# 0.8331754889628621
# 0.7549280815924713
# 0.8818008297130734
# 0.8481734687089271
# 0.9189149188964728
# 0.7883562028536575
# 0.767547532082806
# 0.8644510694573849
# 0.8788329908784824
# 0.7951208705601946
# 0.95758865756476
# 0.9352977792732957
# 0.7065212213679255
# 0.6824859101378769
# 0.8603922332911197
# 0.7730696710046799
# 0.9388259639278547
# 0.8960589924234569
# 0.8287915798335306
# 0.5839472861219556
# 0.9233113887645017
# 0.949343627031132
# 0.9220479748014545
# 0.6047343946780241
# 0.686138728416047
# 0.9520466636858673
# 0.9252504343381008
# 0.6474060924695195
# 0.90993475368517
# 0.9826823535648898
# 0.7895210987434097

# %%
'''Add OKS to the metrics dataframe'''
metrics['OKS'] = OKSs

# %%
plt.hist(metrics['OKS'])
# Out:
# (array([          1,           3,           2,           1,           7,          10,          10,          22,          31,          25]),
#  array([    0.26836,     0.33979,     0.41122,     0.48265,     0.55409,     0.62552,     0.69695,     0.76838,     0.83982,     0.91125,     0.98268]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(metrics['OKS'])
# Out:
# (array([          1,           3,           2,           5,           5,           7,           8,          26,          30,          25]),
#  array([    0.66334,     0.69463,     0.72592,     0.75722,     0.78851,     0.81981,      0.8511,      0.8824,     0.91369,     0.94498,     0.97628]),
#  <BarContainer object of 10 artists>)

# %%
metrics['OKS'].min()
# Out:
# 0.2683564062103378

# %%
# Let's see what the best and worst keypoint images look like

worstOKSidx = metrics['OKS'].nsmallest(1).index.to_numpy()[0]
bestOKSidx = metrics['OKS'].nlargest(1).index.to_numpy()[0]

# %%
plot_output(worstOKSidx)

# %%
plot_output(bestOKSidx)

# %%
#What about the second worst?

badOKSidx = metrics['OKS'].nsmallest(2).index.to_numpy()[1]
plot_output(badOKSidx)

# %% [markdown]
# # Other things we can do:
# 1. Compute a head/tail OKS score only considering head and tail points. Then you can compare the OKS with the order YOLO gave versus the reverse order. This would be more interesting in a more diverse set where we get head/tail wrong sometimes
# 2. Assess how good the heads and tails individually were assessed
# 3. Repeat these notebooks with more realistic simulation that includes Noise (done)
# 4. Repeat this for images with multiple tracks
# 5. Train YOLO using Logarithmic colorscale images (done)
# 6. Play around with estimating track angles based on keypoint trajectories and comparing to truth
